# %% [markdown]
# Gráfico imobiliario

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 1. MARGEM LÍQUIDA

# %%
dados = {
    'Empresa': ['ALIANS', 'CCR', 'CYRELA', 'EZTEC', 'IGUATEMI', 'MULTIPLAN'],
    '2022': [19.99, 21.96, 15.86, 30.51, 1.26, 42.80],
    '2023': [128.82, 9.80, 17.68, 22.72, 26.70, 50.28],
    '2024': [29.64, 6.02, 24.12, 27.47, 32.34, 52.70],
    'Média': [59.48, 12.59, 19.22, 26.90, 20.10, 48.59]
}

df = pd.DataFrame(dados)

media_global = 23.50

# %%
empresas = df['Empresa']
m2022 = df['2022']
m2023 = df['2023']
m2024 = df['2024']
media = df['Média']

# Configuração da figura  MESMA COISA DOS GRAFICOS DE ENERGIA
fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras para cada ano
bars_2022 = ax.bar([p - width for p in x], m2022, width, label='2022', color='#66b3ff', edgecolor='black')
bars_2023 = ax.bar(x, m2023, width, label='2023', color='#ffcc99', edgecolor='black')
bars_2024 = ax.bar([p + width for p in x], m2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual por empresa
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha horizontal da média global do setor
ax.axhline(media_global, color='#ff4500', linestyle='--', label='Média Global (23,50%)', linewidth=2)

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Margem Líquida (%)', fontsize=16, fontweight='bold')
ax.set_title('Margem Líquida das Empresas (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Criando legenda estendida com os valores por empresa/ano
numbers_legend = [
    f'{empresa}: {m2022[i]:.2f}% (2022), {m2023[i]:.2f}% (2023), {m2024[i]:.2f}% (2024)'
    for i, empresa in enumerate(empresas)
]

# Legenda extra com os números (no canto inferior direito)
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

# Layout final
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. grau de endividamento

# %%
dados = {
    'Empresa': ['ALIANS', 'CCR', 'CYRELA', 'EZTEC', 'IGUATEMI', 'MULTIPLAN'],
    '2022': [35.88, 76.61, 53.51, 17.97, 48.96, 39.48],
    '2023': [45.39, 76.07, 51.07, 19.97, 46.80, 39.92],
    '2024': [48.20, 76.31, 53.16, 24.49, 46.38, 54.88],
    'Média': [43.16, 76.33, 52.58, 20.81, 47.38, 44.76]
}

df = pd.DataFrame(dados)

# Média global (das médias das empresas)
media_global = 46.07

# %%
empresas = df['Empresa']
d2022 = df['2022']
d2023 = df['2023']
d2024 = df['2024']
media = df['Média']

# Configuração da figura
fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras para cada ano
bars_2022 = ax.bar([p - width for p in x], d2022, width, label='2022', color='#66b3ff', edgecolor='black')
bars_2023 = ax.bar(x, d2023, width, label='2023', color='#ffcc99', edgecolor='black')
bars_2024 = ax.bar([p + width for p in x], d2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual por empresa
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha horizontal da média global do setor
ax.axhline(media_global, color='#ff4500', linestyle='--', label='Média Global (46,07%)', linewidth=2)

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Grau de Endividamento (%)', fontsize=16, fontweight='bold')
ax.set_title('Grau de Endividamento das Empresas (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {d2022[i]:.2f}% (2022), {d2023[i]:.2f}% (2023), {d2024[i]:.2f}% (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

# Layout final
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Rentabilidade do PL

# %%
dados = {
    'Empresa': ['ALIANS', 'CCR', 'CYRELA', 'EZTEC', 'IGUATEMI', 'MULTIPLAN'],
    '2022': [2.82, 35.63, 11.15, 7.54, 0.31, 11.69],
    '2023': [23.13, 14.18, 13.01, 5.23, 7.40, 14.72],
    '2024': [5.74, 9.37, 19.31, 8.78, 9.57, 23.75],
    'Média': [10.56, 19.73, 14.49, 7.18, 5.76, 16.72]
}

df = pd.DataFrame(dados)

# Média global (das médias das empresas)
media_global = 12.53

# %%
empresas = df['Empresa']
roe_2022 = df['2022']
roe_2023 = df['2023']
roe_2024 = df['2024']
media = df['Média']

# Configuração da figura
fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras para cada ano
bars_2022 = ax.bar([p - width for p in x], roe_2022, width, label='2022', color='#66b3ff', edgecolor='black')
bars_2023 = ax.bar(x, roe_2023, width, label='2023', color='#ffcc99', edgecolor='black')
bars_2024 = ax.bar([p + width for p in x], roe_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual por empresa
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha horizontal da média global do setor
ax.axhline(media_global, color='#ff4500', linestyle='--', label='Média Global (12,53%)', linewidth=2)

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Rentabilidade do Patrimônio Líquido (%)', fontsize=16, fontweight='bold')
ax.set_title('Rentabilidade do PL das Empresas (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {roe_2022[i]:.2f}% (2022), {roe_2023[i]:.2f}% (2023), {roe_2024[i]:.2f}% (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

# Layout final
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Composição do Endividamento

# %%
dados = {
    'Empresa': ['Alians', 'CCR', 'Cyrela', 'Eztec', 'Iguatemi', 'Multiplan'],
    '2022': [23.04, 27.80, 41.78, 47.82, 43.34, 30.16],
    '2023': [17.02, 20.41, 38.94, 34.29, 24.97, 30.44],
    '2024': [17.22, 13.60, 32.79, 24.15, 24.87, 22.49],
    'Média': [19.09, 20.60, 37.84, 35.42, 31.06, 27.70]
}

df = pd.DataFrame(dados)

# Média global (das médias das empresas)
media_global = 29.38

# %%
empresas = df['Empresa']
ce_2022 = df['2022']
ce_2023 = df['2023']
ce_2024 = df['2024']
media = df['Média']

# Configuração da figura
fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras para cada ano
bars_2022 = ax.bar([p - width for p in x], ce_2022, width, label='2022', color='#66b3ff', edgecolor='black')
bars_2023 = ax.bar(x, ce_2023, width, label='2023', color='#ffcc99', edgecolor='black')
bars_2024 = ax.bar([p + width for p in x], ce_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual por empresa
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha horizontal da média global do setor
ax.axhline(media_global, color='#ff4500', linestyle='--', label='Média Global (29,38%)', linewidth=2)

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Composição do Endividamento (%)', fontsize=16, fontweight='bold')
ax.set_title('Composição do Endividamento das Empresas (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {ce_2022[i]:.2f}% (2022), {ce_2023[i]:.2f}% (2023), {ce_2024[i]:.2f}% (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

# Layout final
plt.tight_layout()
plt.show()

# %% [markdown]
# 5. Liquidez Corrente

# %%
dados = {
    'Empresa': ['Alians', 'CCR', 'Cyrela', 'Eztec', 'Iguatemi', 'Multiplan'],
    '2022': [3.22, 1.17, 2.48, 4.91, 1.27, 1.37],
    '2023': [1.79, 1.30, 2.83, 6.24, 2.13, 1.42],
    '2024': [1.89, 1.70, 3.27, 6.84, 2.16, 1.43],
    'Média': [2.30, 1.39, 2.86, 6.00, 1.85, 1.41]
}

df = pd.DataFrame(dados)

# Média global (das médias das empresas)
media_global = 2.08

# %%
empresas = df['Empresa']
liq_2022 = df['2022']
liq_2023 = df['2023']
liq_2024 = df['2024']
media = df['Média']

# Configuração da figura
fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras para cada ano
bars_2022 = ax.bar([p - width for p in x], liq_2022, width, label='2022', color='#66b3ff', edgecolor='black')
bars_2023 = ax.bar(x, liq_2023, width, label='2023', color='#ffcc99', edgecolor='black')
bars_2024 = ax.bar([p + width for p in x], liq_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual por empresa
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha horizontal da média global do setor
ax.axhline(media_global, color='#ff4500', linestyle='--', label='Média Global (2,08)', linewidth=2)

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Liquidez Corrente (razão)', fontsize=16, fontweight='bold')
ax.set_title('Liquidez Corrente das Empresas (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {liq_2022[i]:.2f} (2022), {liq_2023[i]:.2f} (2023), {liq_2024[i]:.2f} (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

# Layout final
plt.tight_layout()
plt.show()

# %% [markdown]
# 6. Tempo de Retorno do Capital

# %%
dados = {
    'Empresa': ['ALIANS', 'CCR', 'CYRELA', 'EZTEC', 'IGUATEMI', 'MULTIPLAN'],
    '2022': [18.6, 4.9, 5.8, 7.9, 419.7, 16.1],
    '2023': [4.0, 13.8, 8.5, 15.5, 22.1, 16.7],
    '2024': [11.9, 15.7, 3.4, 5.5, 17.1, 8.2],
    'Média': [11.50, 11.47, 5.90, 9.63, 152.97, 13.67]
}

df = pd.DataFrame(dados)

# Média global das médias das empresas
media_global = 11.48

# %%
empresas = df['Empresa']
pl_2022 = df['2022']
pl_2023 = df['2023']
pl_2024 = df['2024']
media = df['Média']

fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras para cada ano
ax.bar([p - width for p in x], pl_2022, width, label='2022', color='#66b3ff', edgecolor='black')
ax.bar(x, pl_2023, width, label='2023', color='#ffcc99', edgecolor='black')
ax.bar([p + width for p in x], pl_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual por empresa
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha horizontal da média global
ax.axhline(media_global, color='#ff4500', linestyle='--', linewidth=2, label='Média Global (11,48)')

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Tempo de Retorno do Capital (anos)', fontsize=16, fontweight='bold')
ax.set_title('Tempo de Retorno do Capital (P/L) - 2022 a 2024', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda com valores por ano
numbers_legend = [
    f'{empresa}: {pl_2022[i]:.2f} (2022), {pl_2023[i]:.2f} (2023), {pl_2024[i]:.2f} (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# 7. P/VPA

# %%
dados = {
    'Empresa': ['ALIANS', 'CCR', 'CYRELA', 'EZTEC', 'IGUATEMI', 'MULTIPLAN'],
    '2022': [0.52, 4.9, 0.64, 0.6, 1.31, 1.88],
    '2023': [0.92, 13.8, 1.10, 0.81, 1.63, 2.46],
    '2024': [0.69, 15.7, 0.65, 0.49, 1.64, 1.94],
    'Média': [0.71, 11.47, 0.80, 0.63, 1.53, 2.09]
}

df = pd.DataFrame(dados)

# Média global
media_global = 1.16

# %%
empresas = df['Empresa']
pvpa_2022 = df['2022']
pvpa_2023 = df['2023']
pvpa_2024 = df['2024']
media = df['Média']

fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras por ano
ax.bar([p - width for p in x], pvpa_2022, width, label='2022', color='#66b3ff', edgecolor='black')
ax.bar(x, pvpa_2023, width, label='2023', color='#ffcc99', edgecolor='black')
ax.bar([p + width for p in x], pvpa_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média por empresa
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha da média global do setor
ax.axhline(media_global, color='#ff4500', linestyle='--', linewidth=2, label='Média Global (1,16)')

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('P/VPA (R$)', fontsize=16, fontweight='bold')
ax.set_title('Disposição do Investidor (P/VPA) - 2022 a 2024', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica
numbers_legend = [
    f'{empresa}: {pvpa_2022[i]:.2f} (2022), {pvpa_2023[i]:.2f} (2023), {pvpa_2024[i]:.2f} (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# Dividend Yield

# %%
dados = {
    'Empresa': ['ALIANS', 'CCR', 'CYRELA', 'EZTEC', 'IGUATEMI', 'MULTIPLAN'],
    '2022': [3.72, 4.11, 3.87, 2.85, 0.65, 3.39],
    '2023': [7.18, 3.05, 3.73, 1.49, 2.65, 3.40],
    '2024': [5.28, 2.07, 8.45, 10.38, 3.25, 4.93],
    'Média': [5.39, 3.08, 5.35, 4.91, 2.18, 3.91]
}

df = pd.DataFrame(dados)

# Média global do setor
media_global = 4.13

# %%
empresas = df['Empresa']
yield_2022 = df['2022']
yield_2023 = df['2023']
yield_2024 = df['2024']
media = df['Média']

fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras por ano
ax.bar([p - width for p in x], yield_2022, width, label='2022', color='#66b3ff', edgecolor='black')
ax.bar(x, yield_2023, width, label='2023', color='#ffcc99', edgecolor='black')
ax.bar([p + width for p in x], yield_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha da média global
ax.axhline(media_global, color='#ff4500', linestyle='--', linewidth=2, label='Média Global (4,13%)')

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Dividend Yield (%)', fontsize=16, fontweight='bold')
ax.set_title('Dividend Yield das Empresas (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {yield_2022[i]:.2f}% (2022), {yield_2023[i]:.2f}% (2023), {yield_2024[i]:.2f}% (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ebitda

# %%
dados = {
    'Empresa': ['ALIANS', 'CCR', 'CYRELA', 'EZTEC', 'IGUATEMI', 'MULTIPLAN'],
    '2022': [60.44, 60.90, 18.04, 22.44, 64.33, 70.94],
    '2023': [224.80, 40.47, 19.45, 19.28, 68.83, 75.31],
    '2024': [75.62, 32.16, 26.27, 23.02, 72.41, 72.62],
    'Média': [120.29, 44.51, 21.25, 21.58, 68.52, 72.96]
}

df = pd.DataFrame(dados)

# Média global do setor
media_global = 58.19

# %%
empresas = df['Empresa']
ebitda_2022 = df['2022']
ebitda_2023 = df['2023']
ebitda_2024 = df['2024']
media = df['Média']

fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras por ano
ax.bar([p - width for p in x], ebitda_2022, width, label='2022', color='#66b3ff', edgecolor='black')
ax.bar(x, ebitda_2023, width, label='2023', color='#ffcc99', edgecolor='black')
ax.bar([p + width for p in x], ebitda_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha da média global
ax.axhline(media_global, color='#ff4500', linestyle='--', linewidth=2, label=f'Média Global ({media_global})')

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('EBITDA (R$ milhões)', fontsize=16, fontweight='bold')
ax.set_title('EBITDA das Empresas do Setor Imobiliário (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {ebitda_2022[i]:.2f} (2022), {ebitda_2023[i]:.2f} (2023), {ebitda_2024[i]:.2f} (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# NORMALIZAÇÃO DOS PESOS + RANKING

# %%
dados = {
    'Empresa': ['ALIANS', 'CCR', 'CYRELA', 'EZTEC', 'IGUATEMI', 'MULTIPLAN'],
    'Liquidez Corrente': [2.30, 1.39, 2.86, 6.00, 1.85, 1.41],
    'Grau de Endividamento': [43.16, 76.33, 52.58, 20.81, 47.38, 44.76],
    'Composição do Endividamento': [23.04, 27.80, 41.78, 47.82, 43.34, 30.16],
    'Margem Líquida': [59.48, 12.59, 19.22, 26.90, 20.10, 48.59],
    'ROE': [10.56, 19.73, 14.49, 7.18, 5.76, 16.72],
    'P/L': [11.50, 11.47, 5.90, 9.63, 152.97, 13.67],
    'P/VPA': [0.71, 11.47, 0.80, 0.63, 1.53, 2.09],
    'Dividend Yield': [5.39, 3.08, 5.35, 4.91, 2.18, 3.91],
    'EBITDA': [120.29, 44.51, 21.25, 21.58, 68.52, 72.96]  # Média 2022-2024
}

df = pd.DataFrame(dados)

# %%
maior_melhor = ['Liquidez Corrente', 'Margem Líquida', 'ROE', 'Dividend Yield', 'EBITDA']
menor_melhor = ['Grau de Endividamento', 'Composição do Endividamento', 'P/L', 'P/VPA']

for col in maior_melhor:
    df[col + '_norm'] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())

for col in menor_melhor:
    df[col + '_norm'] = 1 - (df[col] - df[col].min()) / (df[col].max() - df[col].min())

# === Pesos balanceados por relevância no setor Imobiliário ===
pesos = {
    'ROE_norm': 0.15,
    'Margem Líquida_norm': 0.15,
    'EBITDA_norm': 0.15,
    'Composição do Endividamento_norm': 0.12,
    'Dividend Yield_norm': 0.10,
    'Grau de Endividamento_norm': 0.10,
    'Liquidez Corrente_norm': 0.08,
    'P/L_norm': 0.08,
    'P/VPA_norm': 0.07
}

# === Score Final e Ranking ===
df['Score Final'] = sum(df[col] * peso for col, peso in pesos.items())
df_ranked = df[['Empresa', 'Score Final']].sort_values(by='Score Final', ascending=False).reset_index(drop=True)
df_ranked.insert(0, 'Posição', range(1, len(df_ranked) + 1))

# %%
# Atualização do gráfico com EBITDA
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(df_ranked['Empresa'], df_ranked['Score Final'], color='#66b3ff', edgecolor='black')
ax.set_title('Ranking Final com 9 Indicadores (Composição Endividamento + EBITDA)', fontsize=16, fontweight='bold')
ax.set_xlabel('Empresa', fontsize=14)
ax.set_ylabel('Score Normalizado', fontsize=14)
ax.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# GRÁFICOS SETOR DE ENERGIA

# %% [markdown]
# 1. LIQUIDEZ CORRENTE

# %%
dados = {
    'Empresa': ['CTEEP', 'TAESA', 'COPEL', 'ENGIE', 'CEMIG'],
    '2022': [2.45, 3.06, 1.30, 1.25, 1.20],
    '2023': [2.46, 2.01, 1.47, 1.46, 0.91],
    '2024': [2.98, 1.23, 1.26, 0.99, 0.86],
    'Média': [2.63, 2.10, 1.34, 1.23, 0.99]
}

df = pd.DataFrame(dados)

# Média global do setor (calculada previamente)
media_global = 1.66

# %%
empresas = df['Empresa']
liq_2022 = df['2022']
liq_2023 = df['2023']
liq_2024 = df['2024']
media = df['Média']

fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras por ano
ax.bar([p - width for p in x], liq_2022, width, label='2022', color='#66b3ff', edgecolor='black')
ax.bar(x, liq_2023, width, label='2023', color='#ffcc99', edgecolor='black')
ax.bar([p + width for p in x], liq_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha da média global
ax.axhline(media_global, color='#ff4500', linestyle='--', linewidth=2, label='Média Global (1,66)')

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Liquidez Corrente', fontsize=16, fontweight='bold')
ax.set_title('Liquidez Corrente das Empresas do Setor de Energia (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {liq_2022[i]:.2f} (2022), {liq_2023[i]:.2f} (2023), {liq_2024[i]:.2f} (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# 2. GRAU DE ENDIVIDAMENTO

# %%
dados = {
    'Empresa': ['CTEEP', 'TAESA', 'COPEL', 'ENGIE', 'CEMIG'],
    '2022': [50.46, 62.61, 57.49, 77.90, 59.41],
    '2023': [53.65, 66.27, 56.66, 76.75, 55.17],
    '2024': [50.24, 66.03, 55.32, 75.49, 54.15],
    'Média': [51.45, 64.97, 56.49, 76.71, 56.24]
}

df = pd.DataFrame(dados)

# Média global do setor
media_global = 61.17

# %%
empresas = df['Empresa']
val_2022 = df['2022']
val_2023 = df['2023']
val_2024 = df['2024']
media = df['Média']

fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras por ano
ax.bar([p - width for p in x], val_2022, width, label='2022', color='#66b3ff', edgecolor='black')
ax.bar(x, val_2023, width, label='2023', color='#ffcc99', edgecolor='black')
ax.bar([p + width for p in x], val_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha da média global
ax.axhline(media_global, color='#ff4500', linestyle='--', linewidth=2, label='Média Global (61,17%)')

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Grau de Endividamento (%)', fontsize=16, fontweight='bold')
ax.set_title('Grau de Endividamento das Empresas do Setor de Energia (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {val_2022[i]:.2f}% (2022), {val_2023[i]:.2f}% (2023), {val_2024[i]:.2f}% (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Rendimento do PL (ROE)

# %%
dados = {
    'Empresa': ['CTEEP', 'TAESA', 'COPEL', 'ENGIE', 'CEMIG'],
    '2022': [16.26, 22.59, 5.44, 31.57, 18.80],
    '2023': [17.70, 20.97, 9.62, 34.93, 23.39],
    '2024': [11.50, 24.41, 10.92, 35.04, 26.00],
    'Média': [15.15, 22.66, 10.92, 33.85, 22.73]
}

df = pd.DataFrame(dados)

# Média global do setor
media_global = 22.66

# %%
empresas = df['Empresa']
val_2022 = df['2022']
val_2023 = df['2023']
val_2024 = df['2024']
media = df['Média']

fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras por ano
ax.bar([p - width for p in x], val_2022, width, label='2022', color='#66b3ff', edgecolor='black')
ax.bar(x, val_2023, width, label='2023', color='#ffcc99', edgecolor='black')
ax.bar([p + width for p in x], val_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha da média global
ax.axhline(media_global, color='#ff4500', linestyle='--', linewidth=2, label='Média Global (22,66%)')

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Rentabilidade do Patrimônio Líquido (ROE) (%)', fontsize=16, fontweight='bold')
ax.set_title('ROE das Empresas do Setor de Energia (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {val_2022[i]:.2f}% (2022), {val_2023[i]:.2f}% (2023), {val_2024[i]:.2f}% (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Margem Líquida

# %%
dados = {
    'Empresa': ['CTEEP', 'TAESA', 'COPEL', 'ENGIE', 'CEMIG'],
    '2022': [46.53, 55.39, 5.24, 22.38, 11.88],
    '2023': [44.60, 40.70, 10.83, 31.90, 15.65],
    '2024': [42.74, 45.56, 12.36, 38.35, 17.88],
    'Média': [44.63, 47.22, 9.48, 30.80, 15.14]
}

df = pd.DataFrame(dados)

# Média global do setor
media_global = 29.45

# %%
empresas = df['Empresa']
val_2022 = df['2022']
val_2023 = df['2023']
val_2024 = df['2024']
media = df['Média']

fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras por ano
ax.bar([p - width for p in x], val_2022, width, label='2022', color='#66b3ff', edgecolor='black')
ax.bar(x, val_2023, width, label='2023', color='#ffcc99', edgecolor='black')
ax.bar([p + width for p in x], val_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha da média global
ax.axhline(media_global, color='#ff4500', linestyle='--', linewidth=2, label='Média Global (29,45%)')

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Margem Líquida (%)', fontsize=16, fontweight='bold')
ax.set_title('Margem Líquida das Empresas do Setor de Energia (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {val_2022[i]:.2f}% (2022), {val_2023[i]:.2f}% (2023), {val_2024[i]:.2f}% (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# 5. Ebitda

# %%
dados = {
    'Empresa': ['CTEEP', 'TAESA', 'COPEL', 'ENGIE', 'CEMIG'],
    '2022': [64.54, 94.26, 18.92, 57.03, 19.33],
    '2023': [63.83, 69.97, 23.64, 67.78, 23.08],
    '2024': [64.88, 77.68, 24.41, 78.03, 28.26],
    'Média': [64.42, 80.64, 22.32, 67.61, 23.56]
}

df = pd.DataFrame(dados)

# Média global do setor (dado simbólico original)
media_global = 64.42

# %%
empresas = df['Empresa']
val_2022 = df['2022']
val_2023 = df['2023']
val_2024 = df['2024']
media = df['Média']

fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras por ano
ax.bar([p - width for p in x], val_2022, width, label='2022', color='#66b3ff', edgecolor='black')
ax.bar(x, val_2023, width, label='2023', color='#ffcc99', edgecolor='black')
ax.bar([p + width for p in x], val_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha da média global
ax.axhline(media_global, color='#ff4500', linestyle='--', linewidth=2, label=f'Média Global ({media_global:,.0f})')

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('EBITDA', fontsize=16, fontweight='bold')
ax.set_title('EBITDA das Empresas do Setor de Energia (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: R${val_2022[i]:,.0f} (2022), R${val_2023[i]:,.0f} (2023), R${val_2024[i]:,.0f} (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# 6. Rendimento de Dividendos

# %%
dados = {
    'Empresa': ['CTEEP', 'TAESA', 'COPEL', 'ENGIE', 'CEMIG'],
    '2022': [4.83, 15.18, 12.29, 9.01, 12.67],
    '2023': [8.59, 10.05, 3.63, 7.59, 16.27],
    '2024': [9.08, 9.63, 4.79, 7.88, 14.66],
    'Média': [7.50, 11.62, 6.90, 8.16, 14.53]
}

df = pd.DataFrame(dados)

# Média global do setor
media_global = 8.16

# %%
empresas = df['Empresa']
val_2022 = df['2022']
val_2023 = df['2023']
val_2024 = df['2024']
media = df['Média']

fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras por ano
ax.bar([p - width for p in x], val_2022, width, label='2022', color='#66b3ff', edgecolor='black')
ax.bar(x, val_2023, width, label='2023', color='#ffcc99', edgecolor='black')
ax.bar([p + width for p in x], val_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha da média global
ax.axhline(media_global, color='#ff4500', linestyle='--', linewidth=2, label='Média Global (8,16%)')

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Rendimento de Dividendos (%)', fontsize=16, fontweight='bold')
ax.set_title('Rendimento de Dividendos das Empresas do Setor de Energia (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {val_2022[i]:.2f}% (2022), {val_2023[i]:.2f}% (2023), {val_2024[i]:.2f}% (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# 7. Disposição do Investidor (P / VPA)

# %%
dados = {
    'Empresa': ['CTEEP', 'TAESA', 'COPEL', 'ENGIE', 'CEMIG'],
    '2022': [0.88, 1.57, 0.93, 3.21, 0.81],
    '2023': [0.95, 1.84, 1.18, 3.54, 0.78],
    '2024': [0.85, 1.64, 1.02, 2.36, 1.28],
    'Média': [0.89, 1.68, 1.04, 3.04, 0.96]
}

df = pd.DataFrame(dados)

# Média global do setor
media_global = 1.04

# %%
empresas = df['Empresa']
val_2022 = df['2022']
val_2023 = df['2023']
val_2024 = df['2024']
media = df['Média']

fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras por ano
ax.bar([p - width for p in x], val_2022, width, label='2022', color='#66b3ff', edgecolor='black')
ax.bar(x, val_2023, width, label='2023', color='#ffcc99', edgecolor='black')
ax.bar([p + width for p in x], val_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha da média global
ax.axhline(media_global, color='#ff4500', linestyle='--', linewidth=2, label='Média Global (1,04)')

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('P/VPA (R$)', fontsize=16, fontweight='bold')
ax.set_title('Disposição do Investidor (P/VPA) - Setor de Energia (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {val_2022[i]:.2f} (2022), {val_2023[i]:.2f} (2023), {val_2024[i]:.2f} (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# 8. Tempo de Retorno Capital

# %%
dados = {
    'Empresa': ['CTEEP', 'TAESA', 'COPEL', 'ENGIE', 'CEMIG'],
    '2022': [5.8, 6.9, 17.0, 10.2, 4.3],
    '2023': [4.8, 8.8, 12.3, 10.1, 3.3],
    '2024': [8.69, 6.7, 9.3, 6.7, 4.9],
    'Média': [6.43, 7.46, 12.86, 9.00, 4.16]
}

df = pd.DataFrame(dados)

# Média global do setor
media_global = 7.46

# %%
empresas = df['Empresa']
val_2022 = df['2022']
val_2023 = df['2023']
val_2024 = df['2024']
media = df['Média']

fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras por ano
ax.bar([p - width for p in x], val_2022, width, label='2022', color='#66b3ff', edgecolor='black')
ax.bar(x, val_2023, width, label='2023', color='#ffcc99', edgecolor='black')
ax.bar([p + width for p in x], val_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha da média global
ax.axhline(media_global, color='#ff4500', linestyle='--', linewidth=2, label='Média Global (7,46)')

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Tempo de Retorno do Capital (P/L)', fontsize=16, fontweight='bold')
ax.set_title('Tempo de Retorno do Capital das Empresas do Setor de Energia (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {val_2022[i]:.2f} (2022), {val_2023[i]:.2f} (2023), {val_2024[i]:.2f} (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# 9. Composição do Endividamento

# %%
dados = {
    'Empresa': ['CTEEP', 'TAESA', 'COPEL', 'ENGIE', 'CEMIG'],
    '2022': [8.23, 9.51, 25.05, 19.80, 35.14],
    '2023': [13.49, 13.76, 29.43, 18.86, 43.15],
    '2024': [14.05, 18.25, 32.58, 19.22, 43.74],
    'Média': [11.92, 13.84, 29.02, 19.29, 40.67]
}

df = pd.DataFrame(dados)

# Média global do setor
media_global = 19.29

# %%
empresas = df['Empresa']
val_2022 = df['2022']
val_2023 = df['2023']
val_2024 = df['2024']
media = df['Média']

fig, ax = plt.subplots(figsize=(16, 8))
width = 0.25
x = range(len(empresas))

# Barras por ano
ax.bar([p - width for p in x], val_2022, width, label='2022', color='#66b3ff', edgecolor='black')
ax.bar(x, val_2023, width, label='2023', color='#ffcc99', edgecolor='black')
ax.bar([p + width for p in x], val_2024, width, label='2024', color='#99cc99', edgecolor='black')

# Linha da média individual
ax.plot(x, media, label='Média das Empresas', color='#ff6347', marker='o', linestyle='-', linewidth=3, markersize=8)

# Linha da média global
ax.axhline(media_global, color='#ff4500', linestyle='--', linewidth=2, label='Média Global (19,29%)')

# Títulos e rótulos
ax.set_xlabel('Empresas', fontsize=16, fontweight='bold')
ax.set_ylabel('Composição do Endividamento (%)', fontsize=16, fontweight='bold')
ax.set_title('Composição do Endividamento das Empresas do Setor de Energia (2022-2024)', fontsize=18, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(empresas, rotation=45, ha='right', fontsize=12, fontweight='bold')

# Legenda principal
ax.legend(fontsize=12, loc='upper left', bbox_to_anchor=(0.0, -0.2), ncol=3)

# Legenda numérica extra
numbers_legend = [
    f'{empresa}: {val_2022[i]:.2f}% (2022), {val_2023[i]:.2f}% (2023), {val_2024[i]:.2f}% (2024)'
    for i, empresa in enumerate(empresas)
]
fig.legend(numbers_legend, loc='lower right', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 0), ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Normalização dos dados do setor de energia:

# %%
dados = {
    'Empresa': ['CTEEP', 'TAESA', 'COPEL', 'ENGIE', 'CEMIG'],
    'Liquidez Corrente': [2.63, 2.1, 1.34, 1.23, 0.99],
    'Grau de Endividamento': [51.45, 64.97, 56.49, 76.71, 56.24],
    'Composição do Endividamento': [11.92, 13.84, 29.02, 19.29, 40.67 ],
    'Margem Líquida': [44.63, 47.22, 9.48, 30.80, 15.14],
    'ROE': [15.15, 22.66, 10.92, 33.85, 22.73],
    'P/L': [6.43, 7.46, 12.86, 9.0, 4.16],
    'P/VPA': [0.89, 1.68, 1.04, 3.04, 0.96],
    'Dividend Yield': [7.50, 11.62, 6.90, 8.16, 14.53],
    'EBITDA': [64.42, 80.64, 22.32, 67.61, 23.56]
}
df = pd.DataFrame(dados)

# %%
maior_melhor = ['Liquidez Corrente', 'Margem Líquida', 'ROE', 'Dividend Yield', 'EBITDA']
menor_melhor = ['Grau de Endividamento', 'Composição do Endividamento', 'P/L', 'P/VPA']

for col in maior_melhor:
    df[col + '_norm'] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())

for col in menor_melhor:
    df[col + '_norm'] = 1 - (df[col] - df[col].min()) / (df[col].max() - df[col].min())

# === Pesos balanceados por relevância no setor Energia ===
pesos = {
    'ROE_norm': 0.15,
    'Margem Líquida_norm': 0.10,
    'EBITDA_norm': 0.15,
    'Composição do Endividamento_norm': 0.05,
    'Dividend Yield_norm': 0.15,
    'Grau de Endividamento_norm': 0.15,
    'Liquidez Corrente_norm': 0.10,
    'P/L_norm': 0.10,
    'P/VPA_norm': 0.05
}

#Score Final e Ranking 
df['Score Final'] = sum(df[col] * peso for col, peso in pesos.items())
df_ranked = df[['Empresa', 'Score Final']].sort_values(by='Score Final', ascending=False).reset_index(drop=True)
df_ranked.insert(0, 'Posição', range(1, len(df_ranked) + 1))

# %%
# Atualização do gráfico com EBITDA
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(df_ranked['Empresa'], df_ranked['Score Final'], color='#66b3ff', edgecolor='black')
ax.set_title('Ranking Final com 9 Indicadores (Composição Endividamento + EBITDA)', fontsize=16, fontweight='bold')
ax.set_xlabel('Empresa', fontsize=14)
ax.set_ylabel('Score Normalizado', fontsize=14)
ax.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
